# %% [markdown]
# # Full vs Flat Tire Images
#
# ## Classify images of properly Filled and Underfilled Tires

# %% [markdown]
# The Contest and information about the data will be found here :
#
# https://github.com/meshalalsultan/Full_Vs_Flat_Cnn_With_TensorFlow/blob/main/README.md

# %% [markdown]
# I get the data throw kaggle , and split them in respect to eatch class in floder name tire_dataset.zip , witch can found in https://github.com/meshalalsultan/Full_Vs_Flat_Cnn_With_TensorFlow/blob/main/tire_dataset.zip

# %%
from google.colab import drive

drive.mount('/content/drive')
#/content/drive/MyDrive/tire_dataset.zip
# Out:
# Mounted at /content/drive

# %%
import zipfile

# Unzip the file
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/tire_dataset.zip", "r")
zip_ref.extractall()
zip_ref.close()

# %%
ls tire_dataset
# Out:
# test/  train/

# %%
ls tire_dataset/train
# Out:
# flat/  full/  no_tire/

# %%
ls tire_dataset/train/full
# Out:
# 00000.jpg  00038.jpg  00076.jpg  00114.jpg  00152.jpg  00190.jpg  00228.jpg
# 00001.jpg  00039.jpg  00077.jpg  00115.jpg  00153.jpg  00191.jpg  00229.jpg
# 00002.jpg  00040.jpg  00078.jpg  00116.jpg  00154.jpg  00192.jpg  00230.jpg
# 00003.jpg  00041.jpg  00079.jpg  00117.jpg  00155.jpg  00193.jpg  00231.jpg
# 00004.jpg  00042.jpg  00080.jpg  00118.jpg  00156.jpg  00194.jpg  00232.jpg
# 00005.jpg  00043.jpg  00081.jpg  00119.jpg  00157.jpg  00195.jpg  00233.jpg
# 00006.jpg  00044.jpg  00082.jpg  00120.jpg  00158.jpg  00196.jpg  00234.jpg
# 00007.jpg  00045.jpg  00083.jpg  00121.jpg  00159.jpg  00197.jpg  00235.jpg
# 00008.jpg  00046.jpg  00084.jpg  00122.jpg  00160.jpg  00198.jpg  00236.jpg
# 00009.jpg  00047.jpg  00085.jpg  00123.jpg  00161.jpg  00199.jpg  00237.jpg
# 00010.jpg  00048.jpg  00086.jpg  00124.jpg  00162.jpg  00200.jpg  00238.jpg
# 00011.jpg  00049.jpg  00087.jpg  00125.jpg  00163.jpg  00201.jpg  00239.jpg
# 00012.jpg  00050.jpg  00088.jpg  00126.jpg  00164.jpg  00202.jpg  00240.jpg
# 00013.jpg  00051.jpg  00089.jpg  00127.jpg  00165.jpg  00203.jpg  00241.jpg
# 00014.jpg  00052.jpg  00090.jpg  00128.jpg  00166.jpg  00204.jpg  00242.jpg
# 00015.jpg  00053.jpg  00091.jpg  00129.jpg  00167.jpg  00205.jpg  00243.jpg
# 00016.jpg  00054.jpg  00092.jpg  00130.jpg  00168.jpg  00206.jpg  00244.jpg
# 00017.jpg  00055.jpg  00093.jpg  00131.jpg  00169.jpg  00207.jpg  00245.jpg
# 00018.jpg  00056.jpg  00094.jpg  00132.jpg  00170.jpg  00208.jpg  00246.jpg
# 00019.jpg  00057.jpg  00095.jpg  00133.jpg  00171.jpg  00209.jpg  00247.jpg
# 00020.jpg  00058.jpg  00096.jpg  00134.jpg  00172.jpg  00210.jpg  00248.jpg
# 00021.jpg  00059.jpg  00097.jpg  00135.jpg  00173.jpg  00211.jpg  00249.jpg
# 00022.jpg  00060.jpg  00098.jpg  00136.jpg  00174.jpg  00212.jpg  00250.jpg
# 00023.jpg  00061.jpg  00099.jpg  00137.jpg  00175.jpg  00213.jpg  00251.jpg
# 00024.jpg  00062.jpg  00100.jpg  00138.jpg  00176.jpg  00214.jpg  00252.jpg
# 00025.jpg  00063.jpg  00101.jpg  00139.jpg  00177.jpg  00215.jpg  00253.jpg
# 00026.jpg  00064.jpg  00102.jpg  00140.jpg  00178.jpg  00216.jpg  00254.jpg
# 00027.jpg  00065.jpg  00103.jpg  00141.jpg  00179.jpg  00217.jpg  00255.jpg
# 00028.jpg  00066.jpg  00104.jpg  00142.jpg  00180.jpg  00218.jpg  00256.jpg
# 00029.jpg  00067.jpg  00105.jpg  00143.jpg  00181.jpg  00219.jpg  00257.jpg
# 00030.jpg  00068.jpg  00106.jpg  00144.jpg  00182.jpg  00220.jpg  00258.jpg
# 00031.jpg  00069.jpg  00107.jpg  00145.jpg  00183.jpg  00221.jpg  00259.jpg
# 00032.jpg  00070.jpg  00108.jpg  00146.jpg  00184.jpg  00222.jpg
# 00033.jpg  00071.jpg  00109.jpg  00147.jpg  00185.jpg  00223.jpg
# 00034.jpg  00072.jpg  00110.jpg  00148.jpg  00186.jpg  00224.jpg
# 00035.jpg  00073.jpg  00111.jpg  00149.jpg  00187.jpg  00225.jpg
# 00036.jpg  00074.jpg  00112.jpg  00150.jpg  00188.jpg  00226.jpg
# 00037.jpg  00075.jpg  00113.jpg  00151.jpg  00189.jpg  00227.jpg

# %%
import os

# Walk through pizza_steak directory and list number of files
for dirpath, dirnames, filenames in os.walk("tire_dataset"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 2 directories and 1 images in 'tire_dataset'.
# There are 3 directories and 1 images in 'tire_dataset/train'.
# There are 0 directories and 261 images in 'tire_dataset/train/no_tire'.
# There are 0 directories and 261 images in 'tire_dataset/train/flat'.
# There are 0 directories and 261 images in 'tire_dataset/train/full'.
# There are 3 directories and 1 images in 'tire_dataset/test'.
# There are 0 directories and 40 images in 'tire_dataset/test/no_tire'.
# There are 0 directories and 40 images in 'tire_dataset/test/flat'.
# There are 0 directories and 40 images in 'tire_dataset/test/full'.

# %% [markdown]
# ## How many image in eatch class file

# %%
# Another way to find out how many images are in a file
num_full_images_train = len(os.listdir("tire_dataset/train/full"))

num_full_images_train
# Out:
# 261

# %%
num_flat_images_train = len(os.listdir("tire_dataset/train/flat"))

num_flat_images_train
# Out:
# 261

# %%
num_no_tire_images_train = len(os.listdir("tire_dataset/train/no_tire"))

num_no_tire_images_train
# Out:
# 261

# %% [markdown]
# ## Get the class name

# %%
# Get the class names (programmatically, this is much more helpful with a longer list of classes)
import pathlib
import numpy as np
data_dir = pathlib.Path("tire_dataset/train/") # turn our training path into a Python path
class_names = np.array(sorted([item.name for item in data_dir.glob('*')])) # created a list of class_names from the subdirectories
print(class_names)
# Out:
# ['.DS_Store' 'flat' 'full' 'no_tire']

# %% [markdown]
# So now i have 261 image in train for eatch class , and 40 test

# %% [markdown]
# ## View the image and shape function

# %%
# View an image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

def view_random_image(target_dir, target_class):
  # Setup target directory (we'll view images from here)
  target_folder = target_dir+target_class

  # Get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)

  # Read in the image and plot it using matplotlib
  img = mpimg.imread(target_folder + "/" + random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off");

  print(f"Image shape: {img.shape}") # show the shape of the image

  return img

# %%
# View a random image from the training dataset
img = view_random_image(target_dir="tire_dataset/train/",
                        target_class="full")
# Out:
# Image shape: (240, 240, 3)

# %% [markdown]
# # Vesualize the data

# %%
import matplotlib.pyplot as plt
import cv2

# %%
full_img = cv2.imread('/content/tire_dataset/train/full/00000.jpg')
full_img = cv2.cvtColor(full_img,cv2.COLOR_BGR2RGB)

# %%
#Check the type
type(full_img)
# Out:
# numpy.ndarray

# %%
full_img.shape
# Out:
# (240, 240, 3)

# %%
plt.imshow(full_img);

# %% [markdown]
# Check the flat image

# %%
flat_img = cv2.imread('/content/tire_dataset/train/flat/00004.jpg')
flat_img = cv2.cvtColor(flat_img,cv2.COLOR_BGRA2RGB)

# %%
#Check the type
type(full_img)
# Out:
# numpy.ndarray

# %%
full_img.shape
# Out:
# (240, 240, 3)

# %%
plt.imshow(full_img);

# %% [markdown]
# #Preprosess the image and generate more data

# %% [markdown]
# scale the image from 0 , 1
# by deviding /255

# %%
#Test the scale
img/255
# Out:
# array([[[0.53333333, 0.53333333, 0.53333333],
#         [0.53333333, 0.53333333, 0.53333333],
#         [0.52941176, 0.52941176, 0.52941176],
#         ...,
#         [0.20392157, 0.20392157, 0.20392157],
#         [0.20392157, 0.20392157, 0.20392157],
#         [0.20392157, 0.20392157, 0.20392157]],
#
#        [[0.53333333, 0.53333333, 0.53333333],
#         [0.53333333, 0.53333333, 0.53333333],
#         [0.52941176, 0.52941176, 0.52941176],
#         ...,
#         [0.20392157, 0.20392157, 0.20392157],
#         [0.20392157, 0.20392157, 0.20392157],
#         [0.20392157, 0.20392157, 0.20392157]],
#
#        [[0.5372549 , 0.5372549 , 0.5372549 ],
#         [0.53333333, 0.53333333, 0.53333333],
#         [0.52941176, 0.52941176, 0.52941176],
#         ...,
#         [0.20392157, 0.20392157, 0.20392157],
#         [0.20392157, 0.20392157, 0.20392157],
#         [0.20392157, 0.20392157, 0.20392157]],
#
#        ...,
#
#        [[0.68235294, 0.68235294, 0.68235294],
#         [0.67843137, 0.67843137, 0.67843137],
#         [0.6745098 , 0.6745098 , 0.6745098 ],
#         ...,
#         [0.44313725, 0.44313725, 0.44313725],
#         [0.44313725, 0.44313725, 0.44313725],
#         [0.44705882, 0.44705882, 0.44705882]],
#
#        [[0.67843137, 0.67843137, 0.67843137],
#         [0.67843137, 0.67843137, 0.67843137],
#         [0.6745098 , 0.6745098 , 0.6745098 ],
#         ...,
#         [0.44705882, 0.44705882, 0.44705882],
#         [0.44705882, 0.44705882, 0.44705882],
#         [0.45098039, 0.45098039, 0.45098039]],
#
#        [[0.67843137, 0.67843137, 0.67843137],
#         [0.67843137, 0.67843137, 0.67843137],
#         [0.6745098 , 0.6745098 , 0.6745098 ],
#         ...,
#         [0.45098039, 0.45098039, 0.45098039],
#         [0.45098039, 0.45098039, 0.45098039],
#         [0.45490196, 0.45490196, 0.45490196]]])

# %% [markdown]
# ## Zoom , Scale , rotate ,flip , rescale

# %%
import tensorflow as tf
import keras
from keras.preprocessing.image import ImageDataGenerator

# %%
img_gen = ImageDataGenerator( rotation_range=30 , #rotate the image by 30%
                             width_shift_range=0.1, #shift the img width by max 10%
                             height_shift_range=0.1, #shift the img heigh bay max 10%
                             rescale=1/255, #rescale img by normalize it
                             shear_range=0.2, #cutting away part of the img as buffer 
                             zoom_range=0.2, #zoom in be 20%
                             horizontal_flip=True,
                             fill_mode='nearest')

# %%
plt.imshow(img_gen.random_transform(full_img));

# %%
plt.imshow(img_gen.random_transform(full_img))

# %%
plt.imshow(img_gen.random_transform(flat_img))

# %%
plt.imshow(img_gen.random_transform(flat_img));

# %% [markdown]
# # Building the model

# %% [markdown]
# ## Model_1

# %% [markdown]
# build the model without add target_size=(240,240) in flow_from function

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#set random seed
tf.random.set_seed(42)

#Preprosses the data ( get them all in scale)
train_datagen = ImageDataGenerator( rotation_range=30 , #rotate the image by 30%
                             width_shift_range=0.1, #shift the img width by max 10%
                             height_shift_range=0.1, #shift the img heigh bay max 10%
                             rescale=1/255, #rescale img by normalize it
                             shear_range=0.2, #cutting away part of the img as buffer 
                             zoom_range=0.2, #zoom in be 20%
                             horizontal_flip=True,
                             fill_mode='nearest')

valied_datagen = ImageDataGenerator( rotation_range=30 , #rotate the image by 30%
                             width_shift_range=0.1, #shift the img width by max 10%
                             height_shift_range=0.1, #shift the img heigh bay max 10%
                             rescale=1/255, #rescale img by normalize it
                             shear_range=0.2, #cutting away part of the img as buffer 
                             zoom_range=0.2, #zoom in be 20%
                             horizontal_flip=True,
                             fill_mode='nearest')

#Setup the train and test directories
train_dir = 'tire_dataset/train/'
test_dir = 'tire_dataset/test/'

#Import data from directories and turn it into batches
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=32,
                                               target_size=(240,240),
                                               class_mode='categorical',
                                               seed=42)

valid_data = valied_datagen.flow_from_directory(test_dir,
                                                batch_size=32,
                                                target_size=(240,240),
                                                class_mode='categorical',
                                                seed=42)


#Create CNN Models
model_1 = tf.keras.Sequential([
  tf.keras.layers.Conv2D(filters=10,
                        kernel_size=3,
                        activation='relu',
                        input_shape=(240,240,3)),
  tf.keras.layers.Conv2D(10,3,activation='relu'),
  tf.keras.layers.MaxPool2D(pool_size=2,padding='valid'),
  tf.keras.layers.Conv2D(10,3,activation='relu'),
  tf.keras.layers.Conv2D(10,3,activation='relu'),
  tf.keras.layers.MaxPool2D(2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(3, activation='softmax') #3 class output
])

#compile Model_1
model_1.compile(loss='categorical_crossentropy',
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

#Fit Model_1
history_1 = model_1.fit(train_data,
                      epochs=5,
                      steps_per_epoch=len(train_data),
                      validation_data=valid_data,
                      validation_steps=len(valid_data))
# Out:
# Found 780 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.
# Epoch 1/5
# 25/25 [==============================] - 46s 557ms/step - loss: 0.7789 - accuracy: 0.6410 - val_loss: 0.5630 - val_accuracy: 0.6917
# Epoch 2/5
# 25/25 [==============================] - 13s 526ms/step - loss: 0.5596 - accuracy: 0.7064 - val_loss: 0.4982 - val_accuracy: 0.7167
# Epoch 3/5
# 25/25 [==============================] - 13s 522ms/step - loss: 0.5693 - accuracy: 0.6846 - val_loss: 0.6028 - val_accuracy: 0.6750
# Epoch 4/5
# 25/25 [==============================] - 13s 525ms/step - loss: 0.5215 - accuracy: 0.7359 - val_loss: 0.4417 - val_accuracy: 0.7667
# Epoch 5/5
# 25/25 [==============================] - 13s 531ms/step - loss: 0.4350 - accuracy: 0.7487 - val_loss: 0.4333 - val_accuracy: 0.7667

# %% [markdown]
# It's good .!
# Model_1 did greate job with losses = 0.45 , and accuracy of the model = 0.75
#
# The model got ~75% accouracy on the training set , and 77% on the test set.

# %% [markdown]
# ## Check Model_1

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 238, 238, 10)      280
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 236, 236, 10)      910
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 118, 118, 10)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 116, 116, 10)      910
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 114, 114, 10)      910
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 57, 57, 10)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32490)             0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 97473
# =================================================================
# Total params: 100,483
# Trainable params: 100,483
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model_2

# %% [markdown]
# run the same model but i will rehape the image size to be (224,224,3)

# %%
# Set the seed 
tf.random.set_seed(42)

#Import data from directories and turn it into batches
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=32,
                                               target_size=(224,224),
                                               class_mode='categorical',
                                               seed=42)

valid_data = valied_datagen.flow_from_directory(test_dir,
                                                batch_size=32,
                                                target_size=(224,224),
                                                class_mode='categorical',
                                                seed=42)

#Create the model with tensorflow playground model
model_2 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(224,224,3)),
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(4,activation='relu'),
    tf.keras.layers.Dense(3,activation='softmax')
])

#Compile Model_2
model_2.compile(loss='categorical_crossentropy',
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

#Fit Model_2
model_2.fit(train_data,
            epochs=5,
            steps_per_epoch=len(train_data),
            validation_data=valid_data,
            validation_steps=len(valid_data))
# Out:
# Found 780 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.
# Epoch 1/5
# 25/25 [==============================] - 12s 465ms/step - loss: 4.2738 - accuracy: 0.3500 - val_loss: 2.1318 - val_accuracy: 0.2750
# Epoch 2/5
# 25/25 [==============================] - 11s 440ms/step - loss: 1.4609 - accuracy: 0.3205 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 3/5
# 25/25 [==============================] - 11s 440ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 4/5
# 25/25 [==============================] - 11s 446ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 5/5
# 25/25 [==============================] - 11s 445ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333

# %% [markdown]
# Note Work ..!
#
# The Image shape change it make the model bad on training with 5 epochs , i will try to increes the epoch to = 20, so that the model can take more chance to learn

# %% [markdown]
# ## Model_3

# %%
#Set Seed
tf.random.set_seed(42)

#Create the model
model_3 = tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(224,224,3)),
  tf.keras.layers.Dense(4, activation='relu'),
  tf.keras.layers.Dense(4, activation='relu'),
  tf.keras.layers.Dense(3,activation='softmax')
])

#Compile Model_3
model_3.compile(loss='categorical_crossentropy',
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

#Fit Model_3
history_3 = model_3.fit(train_data,
                        epochs=20,
                        steps_per_epoch=len(train_data),
                        validation_data=valid_data,
                        validation_steps=len(valid_data))
# Out:
# Epoch 1/20
# 25/25 [==============================] - 12s 474ms/step - loss: 1.5284 - accuracy: 0.3154 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 2/20
# 25/25 [==============================] - 11s 444ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 3/20
# 25/25 [==============================] - 11s 440ms/step - loss: 1.0987 - accuracy: 0.3269 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 4/20
# 25/25 [==============================] - 11s 442ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 5/20
# 25/25 [==============================] - 11s 442ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 6/20
# 25/25 [==============================] - 11s 440ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 7/20
# 25/25 [==============================] - 11s 443ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 8/20
# 25/25 [==============================] - 11s 443ms/step - loss: 1.0987 - accuracy: 0.3231 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 9/20
# 25/25 [==============================] - 11s 441ms/step - loss: 1.0987 - accuracy: 0.3167 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 10/20
# 25/25 [==============================] - 11s 444ms/step - loss: 1.0987 - accuracy: 0.3205 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 11/20
# 25/25 [==============================] - 11s 444ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 12/20
# 25/25 [==============================] - 11s 439ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 13/20
# 25/25 [==============================] - 11s 444ms/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 14/20
# 25/25 [==============================] - 11s 443ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 15/20
# 25/25 [==============================] - 11s 438ms/step - loss: 1.0987 - accuracy: 0.2962 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 16/20
# 25/25 [==============================] - 11s 441ms/step - loss: 1.0987 - accuracy: 0.3167 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 17/20
# 25/25 [==============================] - 11s 443ms/step - loss: 1.0987 - accuracy: 0.3090 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 18/20
# 25/25 [==============================] - 11s 438ms/step - loss: 1.0987 - accuracy: 0.3192 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 19/20
# 25/25 [==============================] - 11s 438ms/step - loss: 1.0987 - accuracy: 0.3128 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 20/20
# 25/25 [==============================] - 11s 450ms/step - loss: 1.0986 - accuracy: 0.3218 - val_loss: 1.0986 - val_accuracy: 0.3333

# %% [markdown]
# So , It seems our model not learning anything .!
#
# for model_4 i will try to give the model more nuron to train with 4 > 100, and add extra layers

# %% [markdown]
# ## Model_4

# %%
#Set random Seed
tf.random.set_seed(42)

#Greate Model_4
model_4 = tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(224,224,3)),
  tf.keras.layers.Dense(100 , activation='relu'),
  tf.keras.layers.Dense(100 , activation='relu'),
  tf.keras.layers.Dense(100 ,activation='relu'),
  tf.keras.layers.Dense(3, activation='softmax')
])

#Compile Model_4
model_4.compile(loss='categorical_crossentropy',
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

#Fit Model_4
history_4 = model_4.fit(train_data,
                        epochs=20,
                        steps_per_epoch=len(train_data),
                        validation_data=valid_data,
                        validation_steps=len(valid_data))
# Out:
# Epoch 1/20
# 25/25 [==============================] - 12s 467ms/step - loss: 7.8740 - accuracy: 0.4654 - val_loss: 1.8554 - val_accuracy: 0.5000
# Epoch 2/20
# 25/25 [==============================] - 11s 448ms/step - loss: 2.2204 - accuracy: 0.5808 - val_loss: 1.4703 - val_accuracy: 0.6000
# Epoch 3/20
# 25/25 [==============================] - 11s 438ms/step - loss: 1.2591 - accuracy: 0.6385 - val_loss: 1.3606 - val_accuracy: 0.6500
# Epoch 4/20
# 25/25 [==============================] - 11s 438ms/step - loss: 0.8568 - accuracy: 0.6718 - val_loss: 1.1701 - val_accuracy: 0.6667
# Epoch 5/20
# 25/25 [==============================] - 11s 441ms/step - loss: 0.9721 - accuracy: 0.6667 - val_loss: 1.8168 - val_accuracy: 0.5333
# Epoch 6/20
# 25/25 [==============================] - 11s 446ms/step - loss: 0.9073 - accuracy: 0.6833 - val_loss: 1.1984 - val_accuracy: 0.6667
# Epoch 7/20
# 25/25 [==============================] - 11s 442ms/step - loss: 1.0032 - accuracy: 0.6526 - val_loss: 0.6501 - val_accuracy: 0.6750
# Epoch 8/20
# 25/25 [==============================] - 11s 443ms/step - loss: 1.0114 - accuracy: 0.6423 - val_loss: 0.5969 - val_accuracy: 0.6750
# Epoch 9/20
# 25/25 [==============================] - 11s 443ms/step - loss: 0.5520 - accuracy: 0.7321 - val_loss: 0.4687 - val_accuracy: 0.7667
# Epoch 10/20
# 25/25 [==============================] - 11s 441ms/step - loss: 0.6590 - accuracy: 0.7000 - val_loss: 0.6512 - val_accuracy: 0.6417
# Epoch 11/20
# 25/25 [==============================] - 11s 444ms/step - loss: 0.5167 - accuracy: 0.7500 - val_loss: 0.4256 - val_accuracy: 0.7417
# Epoch 12/20
# 25/25 [==============================] - 11s 444ms/step - loss: 0.4940 - accuracy: 0.7692 - val_loss: 0.5263 - val_accuracy: 0.7583
# Epoch 13/20
# 25/25 [==============================] - 11s 440ms/step - loss: 0.6378 - accuracy: 0.6859 - val_loss: 0.6881 - val_accuracy: 0.6667
# Epoch 14/20
# 25/25 [==============================] - 11s 440ms/step - loss: 0.5344 - accuracy: 0.7372 - val_loss: 0.6904 - val_accuracy: 0.6667
# Epoch 15/20
# 25/25 [==============================] - 11s 443ms/step - loss: 0.5576 - accuracy: 0.7256 - val_loss: 0.4934 - val_accuracy: 0.7000
# Epoch 16/20
# 25/25 [==============================] - 11s 440ms/step - loss: 0.5515 - accuracy: 0.7192 - val_loss: 0.5294 - val_accuracy: 0.7583
# Epoch 17/20
# 25/25 [==============================] - 11s 439ms/step - loss: 0.4482 - accuracy: 0.7577 - val_loss: 0.4948 - val_accuracy: 0.7667
# Epoch 18/20
# 25/25 [==============================] - 11s 439ms/step - loss: 0.4864 - accuracy: 0.7603 - val_loss: 0.5906 - val_accuracy: 0.6250
# Epoch 19/20
# 25/25 [==============================] - 11s 440ms/step - loss: 0.5508 - accuracy: 0.7462 - val_loss: 0.4185 - val_accuracy: 0.8500
# Epoch 20/20
# 25/25 [==============================] - 11s 440ms/step - loss: 0.5188 - accuracy: 0.7282 - val_loss: 0.4341 - val_accuracy: 0.8250

# %% [markdown]
# Good job Model_4 , It's seems model_4 get grate job and learn some pattren in the data , it give 72% accouracy in training data , 72% accouracy in test data.

# %% [markdown]
# So , To tune the model litteil more , the 72% accourcy it's seems not vary good to me :(
#
#
# **BUT**
# Start from `model_5` , i will get back to Conv2d Layers , as i make `model_1` as basline model
#
# and i will start tune the model from there.

# %% [markdown]
# ## Model_5

# %% [markdown]
# I will start same `model_1` with more epochs .

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Activation

# %%
#Set random seed
tf.random.set_seed(42)

#Create the model
model_5= Sequential([
  tf.keras.layers.Conv2D(
      filters=10,
      kernel_size=3,
      activation='relu',
      input_shape=(224,224,3)),
  tf.keras.layers.Conv2D(10,3,activation='relu'),
  tf.keras.layers.MaxPool2D(pool_size=2,padding='valid'),
  tf.keras.layers.Conv2D(10,3,activation='relu'),
  tf.keras.layers.Conv2D(10,3,activation='relu'),
  tf.keras.layers.MaxPool2D(2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(3,activation='softmax')
])

#Compile Model_5
model_5.compile(loss='categorical_crossentropy',
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

#Fit Model_5
history_5 = model_5.fit(train_data,
                      epochs=5,
                      steps_per_epoch=len(train_data),
                      validation_data=valid_data,
                      validation_steps=len(valid_data))
# Out:
# Epoch 1/5
# 25/25 [==============================] - 14s 497ms/step - loss: 0.8026 - accuracy: 0.5667 - val_loss: 0.4789 - val_accuracy: 0.8000
# Epoch 2/5
# 25/25 [==============================] - 11s 460ms/step - loss: 0.5326 - accuracy: 0.7000 - val_loss: 0.4267 - val_accuracy: 0.7750
# Epoch 3/5
# 25/25 [==============================] - 12s 466ms/step - loss: 0.4864 - accuracy: 0.7423 - val_loss: 0.4497 - val_accuracy: 0.7667
# Epoch 4/5
# 25/25 [==============================] - 12s 466ms/step - loss: 0.4815 - accuracy: 0.7244 - val_loss: 0.4190 - val_accuracy: 0.7667
# Epoch 5/5
# 25/25 [==============================] - 12s 467ms/step - loss: 0.4351 - accuracy: 0.7667 - val_loss: 0.3549 - val_accuracy: 0.8167

# %% [markdown]
# ## Model_6

# %% [markdown]
# Start from `model_5` as basline i will :
#
# - Adjast the code
# - But the augamented data witch i create in strter of this notebook
# - add more neuron

# %%
#Create Augmented data
train_data_aug = ImageDataGenerator( rotation_range=30 , #rotate the image by 30%
                             width_shift_range=0.1, #shift the img width by max 10%
                             height_shift_range=0.1, #shift the img heigh bay max 10%
                             rescale=1/255, #rescale img by normalize it
                             shear_range=0.2, #cutting away part of the img as buffer 
                             zoom_range=0.2, #zoom in be 20%
                             horizontal_flip=True,
                             fill_mode='nearest')

# %%
# Import data and augment it from training directory
print("Augmented training images:")
train_data_augmented = train_data_aug.flow_from_directory(train_dir,
                                                                   target_size=(224, 224),
                                                                   batch_size=32,
                                                                   class_mode='categorical',
                                                                   shuffle=False) # Don't shuffle for demonstration purposes, usually a good thing to shuffle
# Out:
# Augmented training images:
# Found 780 images belonging to 3 classes.

# %%
# Get data batch samples
images, labels = train_data.next()
augmented_images, augmented_labels = train_data_augmented.next() # Note: labels aren't augmented, they stay the same

# %%
# Create ImageDataGenerator training instance without data augmentation
train_datagen = ImageDataGenerator(rescale=1/255.) 

# Create ImageDataGenerator test instance without data augmentation
test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
# Create non-augmented data batches
print("Non-augmented training images:")
train_data = train_datagen.flow_from_directory(train_dir,
                                               target_size=(224, 224),
                                               batch_size=32,
                                               class_mode='categorical',
                                               shuffle=True) # Don't shuffle for demonstration purposes

print("Unchanged test images:")
test_data = test_datagen.flow_from_directory(test_dir,
                                             target_size=(224, 224),
                                             batch_size=32,
                                             class_mode='categorical')
# Out:
# Non-augmented training images:
# Found 780 images belonging to 3 classes.
# Unchanged test images:
# Found 120 images belonging to 3 classes.

# %%
# Create the model (this can be our baseline, a 3 layer Convolutional Neural Network)
model_6 = Sequential([
  Conv2D(10, 3, activation='relu', input_shape=(224, 224, 3)),
  MaxPool2D(pool_size=2), # reduce number of features by half
  Conv2D(10, 3, activation='relu'),
  MaxPool2D(),
  Conv2D(10, 3, activation='relu'),
  MaxPool2D(),
  Flatten(),
  Dense(1, activation='sigmoid')
])

# Compile Model_6 
model_6.compile(loss='binary_crossentropy',
                optimizer=Adam(),
                metrics=['accuracy'])

#Fit Model_6
history_6 = model_6.fit(train_data_augmented,
                      epochs=5,
                      steps_per_epoch=len(train_data_augmented),
                      validation_data=test_data,
                      validation_steps=len(test_data))
# Out:
# Epoch 1/5
# 25/25 [==============================] - 11s 411ms/step - loss: 0.6458 - accuracy: 0.6551 - val_loss: 0.6370 - val_accuracy: 0.6667
# Epoch 2/5
# 25/25 [==============================] - 10s 401ms/step - loss: 0.6378 - accuracy: 0.6667 - val_loss: 0.6383 - val_accuracy: 0.6667
# Epoch 3/5
# 25/25 [==============================] - 10s 410ms/step - loss: 0.6378 - accuracy: 0.6667 - val_loss: 0.6370 - val_accuracy: 0.6667
# Epoch 4/5
# 25/25 [==============================] - 10s 420ms/step - loss: 0.6374 - accuracy: 0.6667 - val_loss: 0.6374 - val_accuracy: 0.6667
# Epoch 5/5
# 25/25 [==============================] - 10s 406ms/step - loss: 0.6371 - accuracy: 0.6667 - val_loss: 0.6370 - val_accuracy: 0.6667

# %%
model_6.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 222, 222, 10)      280
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 111, 111, 10)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 109, 109, 10)      910
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 54, 54, 10)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 52, 52, 10)        910
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 26, 26, 10)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 6760)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 6761
# =================================================================
# Total params: 8,861
# Trainable params: 8,861
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Plot Function

# %%
# Plot the validation and training data separately
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(history_6)

# %% [markdown]
# I littel wory about overfitting , Becouse the curv of accouracy , i will try to fix it now

# %% [markdown]
# ## Model_7

# %% [markdown]
# Make the train data shuffeld

# %%
print("Augmented training images:")
train_data_shuffld = train_data_aug.flow_from_directory(train_dir,
                                                                   target_size=(224, 224),
                                                                   batch_size=32,
                                                                   class_mode='categorical',
                                                                   shuffle=True)
# Out:
# Augmented training images:
# Found 780 images belonging to 3 classes.

# %%
# Set the seed 
tf.random.set_seed(42)

#Create Model_7
model_7 = Sequential([
  Conv2D(10,3,activation='relu', input_shape=(224,224,3)),
  MaxPool2D(),
  Conv2D(10,3,activation='relu'),
  MaxPool2D(),
  Conv2D(10,3,activation='relu'),
  MaxPool2D(),
  Flatten(),
  Dense(3,activation='softmax')
])

#Compile Model_7
model_7.compile(loss='categorical_crossentropy',
                optimizer=Adam(),
                metrics=['accuracy']
                )

#Fit the model
history_7 = model_7.fit(train_data_shuffld,
                        epochs=5,
                        steps_per_epoch=len(train_data_shuffld),
                        validation_data=test_data,
                        validation_steps=len(test_data))
# Out:
# Epoch 1/5
# 25/25 [==============================] - 11s 418ms/step - loss: 0.7814 - accuracy: 0.6064 - val_loss: 0.5513 - val_accuracy: 0.6667
# Epoch 2/5
# 25/25 [==============================] - 10s 415ms/step - loss: 0.5263 - accuracy: 0.7090 - val_loss: 0.4838 - val_accuracy: 0.6667
# Epoch 3/5
# 25/25 [==============================] - 10s 414ms/step - loss: 0.5007 - accuracy: 0.6897 - val_loss: 0.4199 - val_accuracy: 0.6833
# Epoch 4/5
# 25/25 [==============================] - 10s 403ms/step - loss: 0.4667 - accuracy: 0.7462 - val_loss: 0.3478 - val_accuracy: 0.8500
# Epoch 5/5
# 25/25 [==============================] - 10s 404ms/step - loss: 0.4278 - accuracy: 0.7872 - val_loss: 0.3001 - val_accuracy: 0.8833

# %%
plot_loss_curves(history_7)

# %% [markdown]
# Its Learning good , So I will Add more epoch AKA:More chance to learn

# %% [markdown]
# ## Model_8

# %%
#Set Seed
tf.random.set_seed(42)

#Create Model_8
model_8 = Sequential([
  Conv2D(10,3,activation='relu',input_shape=(224,224,3)),
  MaxPool2D(),
  Conv2D(10,3,activation='relu'),
  MaxPool2D(),
  Conv2D(10,3,activation='relu'),
  MaxPool2D(),
  Flatten(),
  Dense(3,activation='softmax')
  ])

#Compile Model_8
model_8.compile(loss='categorical_crossentropy',
                optimizer=Adam(),
                metrics=['accuracy'])

#Fit Model_8
history_8 = model_8.fit(train_data_shuffld,
                        epochs=20,
                        steps_per_epoch=len(train_data_shuffld),
                        validation_data=test_data,
                        validation_steps=len(test_data))
# Out:
# Epoch 1/20
# 25/25 [==============================] - 11s 415ms/step - loss: 0.8490 - accuracy: 0.5615 - val_loss: 0.6389 - val_accuracy: 0.6667
# Epoch 2/20
# 25/25 [==============================] - 10s 416ms/step - loss: 0.5460 - accuracy: 0.7000 - val_loss: 0.5104 - val_accuracy: 0.6750
# Epoch 3/20
# 25/25 [==============================] - 10s 404ms/step - loss: 0.5215 - accuracy: 0.7013 - val_loss: 0.4036 - val_accuracy: 0.9250
# Epoch 4/20
# 25/25 [==============================] - 10s 407ms/step - loss: 0.5058 - accuracy: 0.7038 - val_loss: 0.4643 - val_accuracy: 0.6667
# Epoch 5/20
# 25/25 [==============================] - 10s 411ms/step - loss: 0.4673 - accuracy: 0.7487 - val_loss: 0.3229 - val_accuracy: 0.9667
# Epoch 6/20
# 25/25 [==============================] - 10s 410ms/step - loss: 0.4531 - accuracy: 0.7628 - val_loss: 0.3168 - val_accuracy: 0.9333
# Epoch 7/20
# 25/25 [==============================] - 10s 413ms/step - loss: 0.4219 - accuracy: 0.7923 - val_loss: 0.3025 - val_accuracy: 0.8417
# Epoch 8/20
# 25/25 [==============================] - 10s 411ms/step - loss: 0.4513 - accuracy: 0.7462 - val_loss: 0.3739 - val_accuracy: 0.7000
# Epoch 9/20
# 25/25 [==============================] - 10s 410ms/step - loss: 0.4163 - accuracy: 0.7744 - val_loss: 0.3549 - val_accuracy: 0.7667
# Epoch 10/20
# 25/25 [==============================] - 10s 415ms/step - loss: 0.4107 - accuracy: 0.7949 - val_loss: 0.3367 - val_accuracy: 0.8000
# Epoch 11/20
# 25/25 [==============================] - 10s 410ms/step - loss: 0.3912 - accuracy: 0.8064 - val_loss: 0.2967 - val_accuracy: 0.8167
# Epoch 12/20
# 25/25 [==============================] - 10s 412ms/step - loss: 0.3704 - accuracy: 0.8231 - val_loss: 0.3081 - val_accuracy: 0.7917
# Epoch 13/20
# 25/25 [==============================] - 10s 412ms/step - loss: 0.3686 - accuracy: 0.8141 - val_loss: 0.2102 - val_accuracy: 0.9667
# Epoch 14/20
# 25/25 [==============================] - 10s 409ms/step - loss: 0.3414 - accuracy: 0.8513 - val_loss: 0.1596 - val_accuracy: 1.0000
# Epoch 15/20
# 25/25 [==============================] - 10s 412ms/step - loss: 0.3520 - accuracy: 0.8462 - val_loss: 0.1583 - val_accuracy: 0.9750
# Epoch 16/20
# 25/25 [==============================] - 10s 410ms/step - loss: 0.3087 - accuracy: 0.8603 - val_loss: 0.1681 - val_accuracy: 0.9833
# Epoch 17/20
# 25/25 [==============================] - 10s 409ms/step - loss: 0.3116 - accuracy: 0.8615 - val_loss: 0.2580 - val_accuracy: 0.8750
# Epoch 18/20
# 25/25 [==============================] - 10s 408ms/step - loss: 0.3194 - accuracy: 0.8538 - val_loss: 0.4588 - val_accuracy: 0.6833
# Epoch 19/20
# 25/25 [==============================] - 10s 406ms/step - loss: 0.2839 - accuracy: 0.8731 - val_loss: 0.2297 - val_accuracy: 0.8500
# Epoch 20/20
# 25/25 [==============================] - 10s 410ms/step - loss: 0.2937 - accuracy: 0.8615 - val_loss: 0.1865 - val_accuracy: 0.9167

# %%
plot_loss_curves(history_8)

# %% [markdown]
# Here are fairly Good model :)
#
# The model got 82% accuracy ,
# Let me fine tune the neroune or maybe add 1 more layer

# %% [markdown]
# ## Model_9

# %%
#Set Seed
tf.random.set_seed(42)

#Create Model_9
model_9 = Sequential([
  Conv2D(10,3,activation='relu',input_shape=(224,224,3)),
  MaxPool2D(),
  Conv2D(10,3,activation='relu'),
  MaxPool2D(),
  Conv2D(10,3,activation='relu'),
  MaxPool2D(),
  Conv2D(10,3,activation='relu'),
  MaxPool2D(),
  Flatten(),
  Dense(3,activation='softmax')
  ])

#Compile Model_9
model_9.compile(loss='categorical_crossentropy',
                optimizer=Adam(),
                metrics=['accuracy'])

#Fit Model_9
history_9 = model_9.fit(train_data_shuffld,epochs=20,steps_per_epoch=len(train_data_shuffld),validation_data=test_data,validation_steps=len(test_data))
# Out:
# Epoch 1/20
# 25/25 [==============================] - 11s 416ms/step - loss: 1.0422 - accuracy: 0.3603 - val_loss: 0.9581 - val_accuracy: 0.3750
# Epoch 2/20
# 25/25 [==============================] - 10s 412ms/step - loss: 0.6785 - accuracy: 0.6103 - val_loss: 0.5040 - val_accuracy: 0.6083
# Epoch 3/20
# 25/25 [==============================] - 10s 408ms/step - loss: 0.5489 - accuracy: 0.6846 - val_loss: 0.6496 - val_accuracy: 0.6667
# Epoch 4/20
# 25/25 [==============================] - 10s 412ms/step - loss: 0.5204 - accuracy: 0.7026 - val_loss: 0.5667 - val_accuracy: 0.6667
# Epoch 5/20
# 25/25 [==============================] - 10s 413ms/step - loss: 0.4873 - accuracy: 0.7244 - val_loss: 0.4345 - val_accuracy: 0.8333
# Epoch 6/20
# 25/25 [==============================] - 10s 414ms/step - loss: 0.4905 - accuracy: 0.7269 - val_loss: 0.4243 - val_accuracy: 0.8750
# Epoch 7/20
# 25/25 [==============================] - 10s 412ms/step - loss: 0.4637 - accuracy: 0.7346 - val_loss: 0.3952 - val_accuracy: 0.8750
# Epoch 8/20
# 25/25 [==============================] - 10s 412ms/step - loss: 0.4719 - accuracy: 0.7244 - val_loss: 0.4278 - val_accuracy: 0.7833
# Epoch 9/20
# 25/25 [==============================] - 10s 411ms/step - loss: 0.4998 - accuracy: 0.7256 - val_loss: 0.5148 - val_accuracy: 0.6667
# Epoch 10/20
# 25/25 [==============================] - 10s 417ms/step - loss: 0.4376 - accuracy: 0.7795 - val_loss: 0.3687 - val_accuracy: 0.8917
# Epoch 11/20
# 25/25 [==============================] - 10s 413ms/step - loss: 0.4155 - accuracy: 0.7821 - val_loss: 0.3324 - val_accuracy: 0.9333
# Epoch 12/20
# 25/25 [==============================] - 10s 412ms/step - loss: 0.3738 - accuracy: 0.8308 - val_loss: 0.3106 - val_accuracy: 0.8167
# Epoch 13/20
# 25/25 [==============================] - 10s 411ms/step - loss: 0.4047 - accuracy: 0.8103 - val_loss: 0.5219 - val_accuracy: 0.6750
# Epoch 14/20
# 25/25 [==============================] - 10s 410ms/step - loss: 0.3650 - accuracy: 0.8154 - val_loss: 0.2032 - val_accuracy: 1.0000
# Epoch 15/20
# 25/25 [==============================] - 10s 407ms/step - loss: 0.3117 - accuracy: 0.8756 - val_loss: 0.2805 - val_accuracy: 0.7917
# Epoch 16/20
# 25/25 [==============================] - 10s 411ms/step - loss: 0.2869 - accuracy: 0.8821 - val_loss: 0.1344 - val_accuracy: 1.0000
# Epoch 17/20
# 25/25 [==============================] - 10s 409ms/step - loss: 0.3114 - accuracy: 0.8590 - val_loss: 0.1203 - val_accuracy: 1.0000
# Epoch 18/20
# 25/25 [==============================] - 10s 411ms/step - loss: 0.2894 - accuracy: 0.8846 - val_loss: 0.2544 - val_accuracy: 0.8250
# Epoch 19/20
# 25/25 [==============================] - 10s 411ms/step - loss: 0.2880 - accuracy: 0.8833 - val_loss: 0.1172 - val_accuracy: 1.0000
# Epoch 20/20
# 25/25 [==============================] - 10s 413ms/step - loss: 0.2522 - accuracy: 0.9038 - val_loss: 0.0650 - val_accuracy: 1.0000

# %%
plot_loss_curves(history_9)

# %% [markdown]
# # It's Officaly 90% Accouracy :)

# %% [markdown]
# Give the Model more epochs to learn , 20 > 30

# %% [markdown]
# ## Model_10

# %%
#Set Seed
tf.random.set_seed(42)

#Clone Model_9 -> Model_10
model_10 = tf.keras.models.clone_model(model_9)

#Compile Model_10
model_10.compile(loss='categorical_crossentropy',
                 optimizer=Adam(),
                 metrics=['accuracy'])

#Fit Model_10
history_10 = model_10.fit(train_data_shuffld,epochs=30,steps_per_epoch=len(train_data_shuffld),validation_data=test_data,validation_steps=len(test_data))
# Out:
# Epoch 1/30
# 25/25 [==============================] - 11s 426ms/step - loss: 1.0015 - accuracy: 0.3808 - val_loss: 0.8168 - val_accuracy: 0.6583
# Epoch 2/30
# 25/25 [==============================] - 10s 411ms/step - loss: 0.6448 - accuracy: 0.6346 - val_loss: 0.5274 - val_accuracy: 0.6000
# Epoch 3/30
# 25/25 [==============================] - 10s 410ms/step - loss: 0.5211 - accuracy: 0.6974 - val_loss: 0.6037 - val_accuracy: 0.6667
# Epoch 4/30
# 25/25 [==============================] - 10s 410ms/step - loss: 0.5130 - accuracy: 0.7090 - val_loss: 0.5359 - val_accuracy: 0.6917
# Epoch 5/30
# 25/25 [==============================] - 10s 411ms/step - loss: 0.4850 - accuracy: 0.7346 - val_loss: 0.5267 - val_accuracy: 0.6667
# Epoch 6/30
# 25/25 [==============================] - 10s 408ms/step - loss: 0.4715 - accuracy: 0.7231 - val_loss: 0.4281 - val_accuracy: 0.7333
# Epoch 7/30
# 25/25 [==============================] - 10s 407ms/step - loss: 0.4376 - accuracy: 0.7744 - val_loss: 0.4487 - val_accuracy: 0.6750
# Epoch 8/30
# 25/25 [==============================] - 10s 410ms/step - loss: 0.4526 - accuracy: 0.7500 - val_loss: 0.4281 - val_accuracy: 0.8333
# Epoch 9/30
# 25/25 [==============================] - 10s 409ms/step - loss: 0.4347 - accuracy: 0.7679 - val_loss: 0.4035 - val_accuracy: 0.7500
# Epoch 10/30
# 25/25 [==============================] - 10s 408ms/step - loss: 0.3869 - accuracy: 0.8179 - val_loss: 0.3730 - val_accuracy: 0.7917
# Epoch 11/30
# 25/25 [==============================] - 10s 406ms/step - loss: 0.3721 - accuracy: 0.8308 - val_loss: 0.4523 - val_accuracy: 0.6833
# Epoch 12/30
# 25/25 [==============================] - 10s 411ms/step - loss: 0.4123 - accuracy: 0.7949 - val_loss: 0.4044 - val_accuracy: 0.7917
# Epoch 13/30
# 25/25 [==============================] - 10s 410ms/step - loss: 0.3587 - accuracy: 0.8141 - val_loss: 0.3579 - val_accuracy: 0.7500
# Epoch 14/30
# 25/25 [==============================] - 10s 413ms/step - loss: 0.3230 - accuracy: 0.8513 - val_loss: 0.4213 - val_accuracy: 0.6750
# Epoch 15/30
# 25/25 [==============================] - 10s 411ms/step - loss: 0.3243 - accuracy: 0.8538 - val_loss: 0.2370 - val_accuracy: 1.0000
# Epoch 16/30
# 25/25 [==============================] - 10s 410ms/step - loss: 0.3119 - accuracy: 0.8718 - val_loss: 0.1837 - val_accuracy: 1.0000
# Epoch 17/30
# 25/25 [==============================] - 10s 410ms/step - loss: 0.2805 - accuracy: 0.8795 - val_loss: 0.4038 - val_accuracy: 0.6833
# Epoch 18/30
# 25/25 [==============================] - 10s 411ms/step - loss: 0.3455 - accuracy: 0.8256 - val_loss: 0.1940 - val_accuracy: 0.9667
# Epoch 19/30
# 25/25 [==============================] - 10s 411ms/step - loss: 0.3238 - accuracy: 0.8590 - val_loss: 0.1731 - val_accuracy: 1.0000
# Epoch 20/30
# 25/25 [==============================] - 10s 414ms/step - loss: 0.2632 - accuracy: 0.8859 - val_loss: 0.1557 - val_accuracy: 1.0000
# Epoch 21/30
# 25/25 [==============================] - 10s 412ms/step - loss: 0.2856 - accuracy: 0.8782 - val_loss: 0.1248 - val_accuracy: 1.0000
# Epoch 22/30
# 25/25 [==============================] - 10s 407ms/step - loss: 0.2388 - accuracy: 0.9115 - val_loss: 0.1405 - val_accuracy: 0.9917
# Epoch 23/30
# 25/25 [==============================] - 10s 414ms/step - loss: 0.2638 - accuracy: 0.8897 - val_loss: 0.1557 - val_accuracy: 1.0000
# Epoch 24/30
# 25/25 [==============================] - 10s 411ms/step - loss: 0.2429 - accuracy: 0.8923 - val_loss: 0.1981 - val_accuracy: 0.9000
# Epoch 25/30
# 25/25 [==============================] - 10s 410ms/step - loss: 0.1833 - accuracy: 0.9321 - val_loss: 0.1968 - val_accuracy: 0.8833
# Epoch 26/30
# 25/25 [==============================] - 10s 412ms/step - loss: 0.2399 - accuracy: 0.9000 - val_loss: 0.5679 - val_accuracy: 0.6667
# Epoch 27/30
# 25/25 [==============================] - 10s 413ms/step - loss: 0.2363 - accuracy: 0.9013 - val_loss: 0.1329 - val_accuracy: 0.9917
# Epoch 28/30
# 25/25 [==============================] - 10s 413ms/step - loss: 0.1858 - accuracy: 0.9269 - val_loss: 0.1457 - val_accuracy: 0.9500
# Epoch 29/30
# 25/25 [==============================] - 10s 409ms/step - loss: 0.2159 - accuracy: 0.9179 - val_loss: 0.0864 - val_accuracy: 1.0000
# Epoch 30/30
# 25/25 [==============================] - 10s 409ms/step - loss: 0.2336 - accuracy: 0.9128 - val_loss: 0.0762 - val_accuracy: 1.0000

# %% [markdown]
# # It's 93% Accuracy :)

# %%
plot_loss_curves(history_10)

# %%
model_10.evaluate(test_data)
# Out:
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0762 - accuracy: 1.0000
# [0.07618165761232376, 1.0]

# %% [markdown]
# Even thow , The model_10 is overfitting in test_data.
#
# Let's try make predection on new image

# %%
# Create a function to import an image and resize it to be able to be used with our model
def load_and_prep_image(filename, img_shape=224):
  """
  Reads an image from filename, turns it into a tensor
  and reshapes it to (img_shape, img_shape, colour_channel).
  """
  # Read in target file (an image)
  img = tf.io.read_file(filename)

  # Decode the read file into a tensor & ensure 3 colour channels 
  # (our model is trained on images with 3 colour channels and sometimes images have 4 colour channels)
  img = tf.image.decode_image(img, channels=3)

  # Resize the image (to the same size our model was trained on)
  img = tf.image.resize(img, size = [img_shape, img_shape])

  # Rescale the image (get all values between 0 and 1)
  img = img/255.
  return img

# %%
#Create function to scale and get the image in shape of the model
def pred_and_plot(model, filename, class_names):
  """
  Imports an image located at filename, makes a prediction on it with
  a trained model and plots the image with the predicted class as the title.
  """
  # Import the target image and preprocess it
  img = load_and_prep_image(filename)

  # Make a prediction
  pred = model.predict(tf.expand_dims(img, axis=0))

  # Get the predicted class
  pred_class = class_names[int(tf.round(pred)[0][0])]

  # Plot the image and predicted class
  plt.imshow(img)
  plt.title(f"Prediction: {pred_class}")
  plt.axis(False);

# %%
class_names
# Out:
# array(['.DS_Store', 'flat', 'full', 'no_tire'], dtype='<U9')

# %% [markdown]
# # Make Predection

# %%
# Make a prediction using model_10
pred_and_plot(model=model_10, 
              filename="tire0.jpeg", 
              class_names=class_names)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-58-8aa43da2eeaa> in <module>()
#       2 pred_and_plot(model=model_10,
#       3               filename="tire0.jpeg",
# ----> 4               class_names=class_names)
#
# <ipython-input-56-fa9716718a30> in pred_and_plot(model, filename, class_names)
#       6   """
#       7   # Import the target image and preprocess it
# ----> 8   img = load_and_prep_image(filename)
#       9
#      10   # Make a prediction
#
# <ipython-input-55-b0af8d1cae71> in load_and_prep_image(filename, img_shape)
#       6   """
#       7   # Read in target file (an image)
# ----> 8   img = tf.io.read_file(filename)
#       9
#      10   # Decode the read file into a tensor & ensure 3 colour channels
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/io_ops.py in read_file(filename, name)
#     137     A tensor of dtype "string", with the file contents.
#     138   """
# --> 139   return gen_io_ops.read_file(filename, name)
#     140
#     141
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_io_ops.py in read_file(filename, name)
#     554     try:
#     555       return read_file_eager_fallback(
# --> 556           filename, name=name, ctx=_ctx)
#     557     except _core._SymbolicException:
#     558       pass  # Add nodes to the TensorFlow graph.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_io_ops.py in read_file_eager_fallback(filename, name, ctx)
#     577   _attrs = None
#     578   _result = _execute.execute(b"ReadFile", 1, inputs=_inputs_flat,
# --> 579                              attrs=_attrs, ctx=ctx, name=name)
#     580   if _execute.must_record_gradient():
#     581     _execute.record_gradient(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# NotFoundError: tire0.jpeg; No such file or directory [Op:ReadFile]

# %%
pred_and_plot(model=model_10, 
              filename="tire02.jpeg", 
              class_names=class_names)

# %%
pred_and_plot(model=model_10, 
              filename="tire03.jpeg", 
              class_names=class_names)

# %%
pred_and_plot(model=model_10, 
              filename="tire04.jpeg", 
              class_names=class_names)

# %%
pred_and_plot(model=model_10, 
              filename="tire05.jpeg", 
              class_names=class_names)

# %%
pred_and_plot(model=model_10, 
              filename="tire1.jpeg", 
              class_names=class_names)

# %% [markdown]
# #Get the Model in tflite Format Label and Model for flutter

# %%
print (train_data_shuffld.class_indices)

labels = '\n'.join(sorted(train_data_shuffld.class_indices.keys()))

with open('labels.txt', 'w') as f:
  f.write(labels)
# Out:
# {'flat': 0, 'full': 1, 'no_tire': 2}

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model_10)
tflite_model = converter.convert()

with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpbr_037vn/assets
